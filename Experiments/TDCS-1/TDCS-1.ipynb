# %%
import numpy as np
import matplotlib.pyplot as mp
import matplotlib.ticker as tick
import seaborn as sns
import scipy.fftpack as fft
import scipy.io.wavfile as wav
import scipy.stats as stat
import scipy.optimize as opt
import scipy.ndimage as img
import numpy.linalg as la
import numpy.random as rd
import cvxpy as cvx
from sklearn.metrics import mean_squared_error as mse
import time, warnings
import datetime as date
from itertools import permutations
from lbfgs import fmin_lbfgs
from tqdm.notebook import trange, tqdm
from jupyterthemes import jtplot

# %%
jtplot.reset()
sns.set()
sns.set_context('notebook')
mp.rcParams["figure.figsize"] = (5*16/9 ,5)
mp.rcParams["figure.dpi"] = 100

# %%
def dct2(x):
    return fft.dct(fft.dct(x.T, norm='ortho', axis=0).T, norm='ortho', axis=0)

def idct2(x):
    return fft.idct(fft.idct(x.T, norm='ortho', axis=0).T, norm='ortho', axis=0)

def cossim(x, xhat):
    A = x/x.max()
    B = xhat/xhat.max()
    assert len(A) == len(B), "Data coefficients and recovered coefficients are not of equal length"
    num = 0
    for i in range(len(A)):
        num += A[i]*B[i]
    den = la.norm(A, ord=2) * la.norm(B, ord=2)
    return num/den

# %%
def f(t, C, v, d):
    if isinstance(C, list) or isinstance(C, np.ndarray):
        y = np.zeros_like(t)
        for k in range(len(C)):
            y += C[k]*np.sin(2*np.pi*v[k]*t + d[k])
        return y
    else:
        y = C*np.sin(2*np.pi*v*t + d)
        return y

# %%
rd.seed(402)
N = 1000
Ts = 1
t = np.arange(0, N, Ts, float)
C = [0.9]
w = np.array([0.025])/2/np.pi
d = [0]
x = f(t, C, w, d)
M = 50
xi = np.sort(rd.choice(N, M, replace=False))
tx = t[xi]
sigma = 0.05
y = x[xi] + rd.normal(0, sigma, len(xi))

# %%
mp.plot(t, x, "-", label="original")
mp.plot(tx, y, "o", label=fr"sampled + {sigma}$\sigma$ Gaussian noise")
mp.xlabel("time, ms")
mp.ylabel("amplitude")
mp.legend(loc='upper right')
mp.show()

# %%
def yhatm(xi, w):
    assert len(w)%3 == 0, "Parameter vector cannot be broadcast over evaluating function; check if len(parameters) is an integer multiple of 3."
    comp_dim = len(w)//3
    C, v, d = w[:comp_dim], w[comp_dim:2*comp_dim], w[2*comp_dim:]
    y = np.zeros_like(xi, float)
    for m in range(len(xi)):
        for i in range(len(C)):
            y[m] += C[i]*np.sin(v[i]*xi[m]*Ts + d[i])
    return y

def objerr(y, yhat):
#     assert y.shape == yhat.shape, "Signals are not of equal shape."
    res = yhat - y
    Of = np.sum((res)**2)
    return Of

class Bounds:
    def __init__(self, lb, ub):
        self.lb = lb
        self.ub = ub
        self.diff = np.fabs(lb - ub)

# %%
gen_max = 500
NP = 200 # population of each parameter
P = 3 # how many parameters
CR = 0.9
F = 0.8
k_bounds = Bounds(1, 5)
C_bounds = Bounds(-2, 2)
v_bounds = Bounds(0.01, 0.06)
d_bounds = Bounds(0, np.pi)

# %%
for count in trange(gen_max, desc='generation'):
    for kh in [1]:
        pop = rd.random((NP, kh*P))
        pop_denorm = np.zeros_like(pop)
        pop_denorm.T[:kh] = C_bounds.lb + pop.T[:kh]*C_bounds.diff
        pop_denorm.T[kh:2*kh] = v_bounds.lb + pop.T[kh:2*kh]*v_bounds.diff
        pop_denorm.T[2*kh:3*kh] = d_bounds.lb + pop.T[2*kh:3*kh]*d_bounds.diff
        eval_init = np.asarray([yhatm(xi, ind) for ind in pop_denorm])
        cost = np.asarray([objerr(y, eval_init) for ind in eval_init])
        best_idx = np.argmin(cost)
        best = pop_denorm[best_idx]
        D = len(pop.T)
        for i in trange(NP, desc=f'sample, cost: {cost[best_idx]:.2f}', leave=False):
            a, b, c = rd.randint(NP, size=3)
            while a == i:
                a = rd.randint(NP)
            while b == i or b == a:
                b = rd.randint(NP)
            while c == i or c == a or c == b:
                c = rd.randint(NP)
            target = pop[i]
            j = rd.randint(D)
            for k in range(D):
                if rd.random() < CR or k == j:
                    trial = pop[c] + F*(pop[a] - pop[b])
#                     trial = best + F*(pop[a] + pop[b] - pop[c] - pop[d])
                else:
                    trial = pop[i]
                j = (j+1)%D
            trial_denorm = np.zeros_like(trial)
            trial_denorm.T[:kh] = C_bounds.lb + trial.T[:kh]*C_bounds.diff
            trial_denorm.T[kh:2*kh] = v_bounds.lb + trial.T[kh:2*kh]*v_bounds.diff
            trial_denorm.T[2*kh:3*kh] = d_bounds.lb + trial.T[2*kh:3*kh]*d_bounds.diff
            eval_target = yhatm(xi, target)
            eval_trial_denorm = yhatm(xi, trial_denorm)
            score = objerr(y, eval_trial_denorm)
            if score < cost[i]:
                pop[i] = trial
                cost[i] = score
                if score < cost[best_idx]:
                    best_idx = i
                    best = trial_denorm
# Out:
# HBox(children=(FloatProgress(value=0.0, description='generation', max=500.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10493.75', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10065.33', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 12070.17', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11629.40', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10823.24', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10206.22', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11702.75', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10959.69', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10973.36', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11613.42', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10650.42', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11013.85', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 9850.47', max=200.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11637.03', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11037.86', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 9830.35', max=200.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10647.18', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11123.83', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10994.59', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11173.77', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10356.30', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11229.57', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10996.41', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10942.94', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11017.00', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10853.46', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10613.70', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10212.71', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10720.84', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10968.15', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11896.39', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10560.51', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11260.44', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10977.48', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11680.24', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11066.90', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11653.74', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10744.00', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11333.72', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11914.56', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11024.05', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10871.19', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11790.96', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11379.45', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11373.70', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11900.74', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10792.66', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11591.15', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10828.01', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10600.41', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10523.53', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11763.50', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10970.49', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10496.86', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11104.01', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10713.74', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10453.70', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11175.88', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10089.78', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11270.23', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10595.51', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 12327.84', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11237.90', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10408.70', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10702.20', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11098.23', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11102.89', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11015.58', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11214.25', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11483.59', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11614.65', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10997.45', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11636.61', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10892.11', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10789.95', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11067.90', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10446.99', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10770.17', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11251.30', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10950.06', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11235.10', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11092.99', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11452.22', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11138.21', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11432.08', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10338.46', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10784.31', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11321.62', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10271.71', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10471.10', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10077.26', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10603.34', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10874.33', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10108.80', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10805.98', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10872.46', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10439.35', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10809.45', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11067.76', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10055.21', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10612.63', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10467.18', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10428.80', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10586.03', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11315.09', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10844.13', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10531.43', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11159.64', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10845.62', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10690.60', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10752.19', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10291.03', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10740.30', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10508.84', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 9848.41', max=200.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10583.41', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10969.23', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11101.96', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10204.41', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10632.24', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 9935.46', max=200.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11755.20', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10876.41', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10695.08', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10959.08', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11901.31', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10689.35', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11059.44', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10896.87', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11315.97', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10515.65', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11473.10', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10883.30', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 9780.29', max=200.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11484.00', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11256.50', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11408.66', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10913.80', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11641.06', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11289.98', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11460.81', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 9971.68', max=200.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10909.27', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10479.24', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11324.22', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11172.54', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11589.83', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10752.64', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11232.69', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11608.81', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11044.87', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11027.45', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10904.69', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10732.60', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10631.11', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11797.68', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11230.32', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 9932.02', max=200.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10874.24', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10757.58', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10856.80', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10891.60', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10149.62', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11002.92', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 12080.01', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10747.84', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11288.86', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11218.39', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10760.74', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11127.17', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11522.61', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10677.32', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11729.30', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11491.11', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11520.94', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11132.15', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11679.41', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11275.09', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 12124.27', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11791.82', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11376.22', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 12264.99', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11283.11', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11939.03', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11930.87', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10957.51', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10603.75', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10362.24', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10772.77', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10690.46', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10578.85', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10390.38', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10872.74', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11061.38', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11091.40', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11016.81', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10522.14', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10984.25', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10580.66', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10539.35', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11042.80', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10279.57', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11399.04', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11189.49', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10119.79', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10321.57', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10880.08', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10359.96', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11951.85', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10829.56', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10269.71', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10531.09', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 12436.06', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10784.19', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 12010.77', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10943.86', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10722.89', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10072.79', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10104.29', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 9953.05', max=200.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11282.48', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10887.12', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 11504.32', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10218.63', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10735.67', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 10534.04', max=200.0, style=ProgressStyle(d…
# HBox(children=(FloatProgress(value=0.0, description='sample, cost: 